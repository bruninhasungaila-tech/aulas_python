# %%
print (f" Resultado A: { round (12.55 , 1)}")
# Out:
#  Resultado A: 12.6

# %%
print (f" Resultado B: { round (12.45 , 1)}")
# Out:
#  Resultado B: 12.4

# %%
print (f" Resultado C: { round (12.65 , 1)}")
# Out:
#  Resultado C: 12.7

# %%
a=15,874
print (f" Resultado a: { round (15.874 , 2)}")
b= 15,876
print (f" Resultado b: { round (15.876 , 2)}")
c=15,875
print (f" Resultado c: { round (15.875 , 2)}")
d=15,885
print (f" Resultado d: { round (15.885 , 2)}")
# Out:
#  Resultado a: 15.87
#  Resultado b: 15.88
#  Resultado c: 15.88
#  Resultado c: 15.88

# %%
a=0.05
print (f" Resultado a: { round (0.05 , 1)}")
b=0.15
print (f" Resultado b: { round (0.15 , 1)}")
c=9.99
print (f" Resultado c: { round (9.99, 1)}")
# Out:
#  Resultado a: 0.1
#  Resultado a: 0.1
#  Resultado a: 10.0

# %%
a=124.50
print (f" Resultado a: { round (a, 0)}")
b=125.50
print (f" Resultado b: { round (b, 0)}")
# Out:
#  Resultado a: 124.0
#  Resultado b: 126.0
