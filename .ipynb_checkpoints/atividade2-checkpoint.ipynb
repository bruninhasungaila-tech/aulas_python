# %% [markdown]
# Crie um programa que:
# 1. Peça a idade do usuário.
# 2. Mostre na tela:
# ▶ Criança (se for menor de 13 anos)
# ▶ Adolescente (de 13 a 17 anos)
# ▶ Adulto (18 anos ou mais)

# %%
idade= int(input( "Qual sua idade?"))
if(idade <=12):
    print( "Criança")
elif ( idade <= 17):
    print("Adolescente")
else:
    print("Adulto")
# Out:
# Qual sua idade? 39
# Adulto

# %% [markdown]
# Verificar número positivo
# Peça ao usuário um número e verifique:
# Se o número for maior que 0, mostre Numero positivo

# %%
numero= int(input("Digite um número:"))
if(numero) >=0: 
    print("número positivo")
# Out:
# Digite um número: 2
# número positivo

# %% [markdown]
# Verificar maior de idade
# Peça a idade do usuário. Mostre "Maior de idade" se a
# idade for maior ou igual a 18.

# %%
idade = int(input("Qual é sua idade?"))
if (idade >= 18):
    print("Maior de idade")
# Out:
# Qual é sua idade? 39
# Maior de idade

# %% [markdown]
# Peça um número ao usuário. Se o número for maior que
# 10, mostre "Número maior que 10".

# %%
numero= int(input("Digite um número:"))
if(numero) >10: 
    print("número maior que 10")
# Out:
# Digite um número: 5

# %% [markdown]
# Peça um número inteiro. Mostre "Número par" ou
# "Número ímpar".

# %%
numero= int(input("Digite um número:"))
if(numero%2==0): 
    print("número par")
# Out:
# Digite um número: 6
# número par

# %% [markdown]
# Peça a nota do aluno. Se a nota for maior ou igual a 7,
# mostre "Aluno aprovado".

# %%
nota= int(input("Digite a nota:"))
if (numero>=7):
    print(" Aprovado")
else:
    print("Reprovado")
# Out:
# Digite a nota: 5
# Reprovado

# %% [markdown]
# Comparar dois números
# Peça dois números ao usuário. Mostre qual é maior.

# %%
numero1= int(input("Digite o primeiro número:"))
numero2= int(input("Digite o segundo número:"))

if numero1 > numero2:
    print("Número 1 é maior que numero 2")
else:
        print(" Número 2 é maior que o 1")
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 10
#  Número 2 é maior que o 1
