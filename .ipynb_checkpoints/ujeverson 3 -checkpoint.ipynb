# %% [markdown]
# # Arredondando para 2 casas

# %%
print ( round (2.456 , 2) )
# Out:
# 2.46

# %% [markdown]
# # O comportamento com o .5

# %%
print ( round (2.5) )
# Out:
# 2

# %%
print ( round (3.5) )
# Out:
# 4

# %%
print ( round (2.456 , 2) )
# Out:
# 2.46
