# %% [markdown]
# Exercício 1: Crie um programa que mostre na tela:

# %%
a = " Eu estou aprendendo Python"
print(a)
# Out:
#  Eu estou aprendendo Python

# %% [markdown]
# Exercício 2: Crie um programa que mostre:

# %%
a= "Meu nome é Maria."
b= " Eu moro em Recife."
print(a)
print(b)
# Out:
# Meu nome é Maria.
#  Eu moro em Recife.

# %% [markdown]
# Exercício 3: Crie duas variáveis: nome_do_aluno e idade_do_aluno.

# %%
a= nome_do_aluno= "Bruna"
b= idade_do_aluno= "39"
print(" Meu nome é", nome_do_aluno,"e tenho", idade_do_aluno, "anos.")
# Out:
#  Meu nome é Bruna e tenho 39 anos.

# %% [markdown]
# Crie três variáveis: cidade, estado e pais. E mostre:

# %%
cidade= " São Paulo"
estado= " SP"
pais= "Brasil"
print("Eu moro em" + cidade + ", " + estado + ", " + pais)
# Out:
# Eu moro em São Paulo,  SP, Brasil

# %% [markdown]
# Crie um programa que:
# 1 Pergunte o nome do aluno
# 2 Pergunte a cidade onde ele mora
# 3 Mostre a frase: Olá João, você mora em Curitiba.

# %%
entrada = input("Digite o seu nome:")
cidade = input("Qual a cidade onde você mora?")
print("Olá", entrada, " você mora em,",cidade)
# Out:
# Digite o seu nome: Bruna
# Qual a cidade onde você mora? Goiânia
# Olá Bruna   você mora em, Goiânia
