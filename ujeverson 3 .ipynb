# %% [markdown]
# # Arredondando para 2 casas

# %%
print ( round (2.456 , 2) )
# Out:
# 2.46

# %% [markdown]
# # O comportamento com o .5

# %%
print ( round (2.5) )
# Out:
# 2

# %%
print ( round (3.5) )
# Out:
# 4

# %%
a=2.436
b=12.23456987
c= -3.4443
print (round(a,2))
print (round(b,2))
print (round(c,2))
# Out:
# 2.44
# 12.23
# -3.44

# %%
dados=[3, 10, 4, 5, 11, 14, 24]
dados_ord= [ sorted(dados)] #função para colocar os dadps e, ordem (crescente)
dados_ord
# Out:
# [[3, 4, 5, 10, 11, 14, 24]]

# %%
#função para contar o numero de elemento da lista
n= len(dados)
soma= sum(dados)
media= soma/n
print("A lista em ", n, "elementos")
print("A soma dos elemnetos é", soma)
print("A média dos elementos é",media)
# Out:
# A lista em  7 elementos
# A soma dos elemnetos é 71
# A média dos elementos é 10.142857142857142

# %% [markdown]
# a) Arredonde manualmente os valores abaixo para uma casa decimal, aplicando
# estritamente a norma NBR 5891 (ABNT):

# %%
12,55
12,45
12,65
# Out:
# (12, 65)
